# %% [markdown]
# # `jevml` Package Testing
#
# Making sure that jevml loads properly.

# %%
# Enable Auto-reload for jevml changes
# %load_ext autoreload
# %autoreload 2

# %%
import torch

# %%
from jevml.models.linear import SimpleLinear

# %%
# Testing output size matrix
# For a single row vector x^T within inputs X, number of inputs will be
# n, and number of outputs will be m. So W must be nxm.
n_in = 5
n_out = 3
net = SimpleLinear(num_inputs=n_in, num_outputs=n_out)
X = torch.randn([30, n_in])
y_hat = net(X)
